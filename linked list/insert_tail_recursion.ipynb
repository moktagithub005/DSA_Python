# %%
from common import Node,take_input_better,print_LL

head = take_input_better()

print_LL(head)

def insert_at_head(head,data): # O(1)
    newNode = Node(data)
    newNode.next = head
    head = newNode
    return head


# head = insert_at_head(head,100)
# print("After Inserting at Head")
# print_LL(head)

def insert_at_tail(head,data):
    newNode = Node(data)
    if(head is None):
        return newNode # If the list is empty,then newNode becomes the head
    
    temp = head
    while(temp.next != None):
        temp = temp.next

    temp.next = newNode

    return head

def insert_at_tail_recursively(head,data):
    if(head is None): # base
      newNode = Node(data)
      return newNode
      
    head.next = insert_at_tail_recursively(head.next,data)

    return head





def insert_at_index(head,data,index):
    if(index ==0):
        return insert_at_head(head,data)
    
    newNode = Node(data)
    temp = head
    count = 0

    while temp is not None and count < index - 1:
        temp = temp.next
        count+=1

    if(temp is None):
        print("Index out of bounds, please check index")
        return head
    
    newNode.next = temp.next
    temp.next = newNode
    return head


def insert_at_index_recursively(head,data,index):
    if(index ==0):
        return insert_at_head(head,data)
    if(head == None):
        print("Index is out of bounds")
        return head
    
    head.next = insert_at_index_recursively(head.next,data,index-1)

    return head

head = insert_at_index_recursively(head,35,3)
print("After Inserting at Index")
print_LL(head)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from common import Node,take_input_better,print_LL
# ----> 3 head = take_input_better()
#       5 print_LL(head)
#       7 def insert_at_head(head,data): # O(1)
#
# File ~/Desktop/DSA_Python/linked list/common.py:50, in take_input_better()
#      47         tail.next = newNode
#      48         tail = newNode
# ---> 50     value = int(input("Enter the value of Node :- "))
#      52 return head
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# The traceback indicates a `ValueError` in the `take_input_better()` function, which is trying to convert an empty string `''` to an integer using `int()`. The error occurs because the user pressed Enter without typing a number, resulting in an empty input string.
#
# ### How the Code Works
#
# The code provided is for a singly linked list and contains several functions for creating and manipulating it. Here's a breakdown of the key components and how they're intended to work:
#
# ```python
# from common import Node,take_input_better,print_LL
# ```
#
# This line imports three elements from a file named `common.py`:
#
#   - `Node`: A class to represent a single node in the linked list, likely containing `data` and a `next` pointer.
#   - `take_input_better`: A function to take user input and build a linked list. This is where the error originates.
#   - `print_LL`: A function to print the elements of the linked list.
#
# <!-- end list -->
#
# ```python
# head = take_input_better()
# ```
#
# This line calls the `take_input_better()` function to get user input for the linked list. This function is designed to prompt the user to enter numbers for the nodes and build a linked list from them. The error traceback shows that the `ValueError` occurs on line 50 of `common.py` within this function, specifically at the line `value = int(input("Enter the value of Node :- "))`. The `input()` function returns an empty string `''` when the user just presses Enter, and `int('')` raises the `ValueError`.
#
# ```python
# print_LL(head)
# ```
#
# This line attempts to print the linked list, but it's never reached because the program crashes at the previous line due to the `ValueError`.
#
# ### The Linked List Functions
#
# The rest of the code defines various functions to perform operations on the linked list, though none of them are executed in the provided traceback:
#
# **`insert_at_head(head, data)`**
#
#   - This function inserts a new node at the beginning of the linked list.
#   - `newNode = Node(data)`: Creates a new node with the specified data.
#   - `newNode.next = head`: Makes the new node's `next` pointer point to the current head of the list.
#   - `head = newNode`: Updates the `head` to be the new node.
#   - This is an **O(1)** operation because it doesn't need to traverse the list.
#
# **`insert_at_tail(head, data)`**
#
#   - This function adds a new node to the end of the list.
#   - `if(head is None):`: Handles the case where the list is empty.
#   - `temp = head`: Initializes a temporary pointer `temp` to the head.
#   - `while(temp.next != None):`: Traverses the list until `temp` points to the last node (the one whose `next` is `None`).
#   - `temp.next = newNode`: Appends the new node to the end.
#
# **`insert_at_tail_recursively(head, data)`**
#
#   - This function does the same as `insert_at_tail` but using a recursive approach.
#   - `if(head is None):`: The base case, which creates and returns the new node when it reaches the end of the list.
#   - `head.next = insert_at_tail_recursively(head.next, data)`: The recursive step, which calls the function on the rest of the list and links the result back to the current node.
#
# **`insert_at_index(head, data, index)`**
#
#   - This function inserts a new node at a specific `index`.
#   - `if(index == 0):`: Handles the special case of inserting at the head.
#   - It uses a `while` loop to traverse the list to the node just before the target index.
#   - `if(temp is None):`: Checks for an out-of-bounds index.
#   - `newNode.next = temp.next`: Links the new node to the node currently at the target index.
#   - `temp.next = newNode`: Links the previous node to the new node.
#
# **`insert_at_index_recursively(head, data, index)`**
#
#   - A recursive version of `insert_at_index`.
#   - `if(index == 0):`: The base case for insertion at the head.
#   - `if(head == None):`: The base case for an out-of-bounds index.
#   - `head.next = insert_at_index_recursively(head.next, data, index-1)`: The recursive step, which decrements the index and moves to the next node.
#
# <!-- end list -->
#
# ```python
# head = insert_at_index_recursively(head,35,3)
# print("After Inserting at Index")
# print_LL(head)
# ```
#
# These final three lines are the intended final operation: inserting the value `35` at index `3` of the list that was supposed to be created. However, they are never reached due to the initial `ValueError`.
